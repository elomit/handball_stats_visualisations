# %%
import json
import os
import pandas as pd
from os import makedirs
from os.path import isdir

from Analysis import Analysis
from constants import PATH, OUTPUT_DIR, TITLE_IMG_PATH, PPT_FILE_PATH, PDF_FILE_PATH
from parsing import parse_json
from ppt_creation import create_ppt
from pdf_creation import ppt_to_pdf
from shot_analysis import analyze_keeper, analyze_shots
from table_analysis import game_analysis_table
from timeline_analysis import full_game_analysis_new, seconds_per_attack

folder_path = r"C:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\input\Zweite_Ergebnisse_2025"
all_data = pd.DataFrame()


PPT_FILE_PATH =  r"C:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\output\half_season_analysis.ppt"
PDF_FILE_PATH =  r"C:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\output\half_season_analysis.pdf"
TITLE_IMG_PATH = r"C:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\woran-hat-es-gelegen-winner.png"

for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        full_path = os.path.join(folder_path, filename)
        with open(full_path) as json_data:
            data = parse_json(json_data.read())
            json_data.close()
            all_data = pd.concat([data, all_data], ignore_index=True)

# rename position to be more readable
mapping = {
    "LA": "Linksaußen",
    "RA": "Rechtsaußen",
    "KM": "Kreis",
    "L": "Halblinks 6M",
    "R": "Halbrechts 6M",
    "M": "Mitte 6M",
    "RL": "Halblinks 9M",
    "RM": "Mitte 9M",
    "RR": "Halbrecht 9M",
    "K": "Konter",
    "7M": "7M"
}
all_data["location"] = all_data["location"].replace(mapping)

# correct names
all_data.player_name = all_data.player_name.replace({
    'Matthias KloÃŸ' : 'Matthias Kloß',
    'Brian Mathias JÃ¤ger' :  'Brian Mathias Jäger',
    'Nenad PeÅ¡iÄ‡' : 'Nenad Pešić',
    'Axel' : 'Axel Trathnigg',
    'Robert Ã–rtel' : 'Robert Örtel',
    'Martin FlieÃŸ' : 'Martin Fließ',
    'timo' : 'unbekannter Spieler 1',
    'Franz JaÃŸ' : 'unbekannter Spieler 2', 
    'Sven BaumgÃ¤rtner' : 'Sven Baumgärtner'
}
)

# Create Analyses
analysis = Analysis(TITLE_IMG_PATH,6,7, 0.25, 2)

analysis.add_analysis(full_game_analysis_new(all_data))
analysis.add_analysis(game_analysis_table(all_data,mapping))
analysis.add_analysis(analyze_shots(all_data))
analysis.add_analysis(analyze_keeper(all_data))

# Create ppt
ppt = create_ppt(analysis)

try:
    ppt.save(PPT_FILE_PATH)
except PermissionError:
    print("Kollege! Mach die PowerPoint zu, es zieht! Dann nochmal probieren bitte (-_-)")
    os.system("TASKKILL /F /IM powerpnt.exe")


try:
    ppt_to_pdf(PPT_FILE_PATH, PDF_FILE_PATH)
    print('PDF wurde erstellt.')
except:
    print('PDF muss noch erstellt werden.')
# Out:
# {'actions': [{'timestamp': 35, 'location': 'RA', 'own_team': True, 'type': 'Tor', 'player': {'number': 8, 'player_name': 'timo', 'position': 'HL'}, 'x': '13', 'y': '18'}, {'timestamp': 54, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 10, 'player_name': 'Robert Ã–rtel', 'position': 'RA'}, 'x': '12', 'y': '8'}, {'timestamp': 97, 'location': 'L', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '10', 'y': '15'}, {'timestamp': 104, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '65', 'y': '10'}, {'timestamp': 134, 'location': 'R', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 8, 'player_name': 'timo', 'position': 'HL'}, 'x': '87', 'y': '62'}, {'timestamp': 172, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '71', 'y': '8'}, {'timestamp': 224, 'location': 'R', 'own_team': True, 'type': 'Tor', 'player': {'number': 10, 'player_name': 'Robert Ã–rtel', 'position': 'RA'}, 'x': '85', 'y': '30'}, {'timestamp': 230, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '85', 'y': '48'}, {'timestamp': 258, 'location': 'KM', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 80, 'player_name': ' Sven', 'position': 'KM'}, 'x': '91', 'y': '31'}, {'timestamp': 286, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '89', 'y': '41'}, {'timestamp': 317, 'location': 'LA', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '75', 'y': '8'}, {'timestamp': 350, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '5', 'y': '7'}, {'timestamp': 389, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 8, 'player_name': 'timo', 'position': 'HL'}, 'x': '88', 'y': '51'}, {'timestamp': 412, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '91', 'y': '64'}, {'timestamp': 426, 'location': 'L', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 37, 'player_name': 'Christoph Stadelmaier', 'position': 'RL'}, 'x': '83', 'y': '46'}, {'timestamp': 468, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '8', 'y': '64'}, {'timestamp': 477, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '12', 'y': '6'}, {'timestamp': 508, 'location': 'RM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 513, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '90', 'y': '19'}, {'timestamp': 537, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 37, 'player_name': 'Christoph Stadelmaier', 'position': 'RL'}, 'x': '90', 'y': '24'}, {'timestamp': 611, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 56, 'player_name': 'Erik Wittstock', 'position': 'LA'}, 'x': '91', 'y': '72'}, {'timestamp': 647, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 20, 'player_name': 'Thomas Dreiseitel', 'position': 'TW'}, 'x': '53', 'y': '84'}, {'timestamp': 671, 'location': 'M', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 8, 'player_name': 'timo', 'position': 'HL'}, 'x': '90', 'y': '13'}, {'timestamp': 699, 'location': 'RA', 'own_team': True, 'type': 'Tor', 'player': {'number': 10, 'player_name': 'Robert Ã–rt ...
# {'actions': [{'timestamp': 32, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '82', 'y': '22'}, {'timestamp': 57, 'location': 'RM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 64, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '-1', 'y': '-1'}, {'timestamp': 145, 'location': 'RM', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 17, 'player_name': 'Florian Denker', 'position': 'KM'}, 'x': '22', 'y': '85'}, {'timestamp': 159, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '85', 'y': '76'}, {'timestamp': 177, 'location': 'RL', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 208, 'location': 'RM', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 218, 'location': 'R', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 1, 'player_name': 'Sebastian Krzizek', 'position': 'RM'}, 'x': '8', 'y': '17'}, {'timestamp': 232, 'location': 'M', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '47', 'y': '86'}, {'timestamp': 262, 'location': 'R', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 18, 'player_name': 'Axel', 'position': 'RA'}, 'x': '80', 'y': '32'}, {'timestamp': 274, 'location': '7M', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '89', 'y': '42'}, {'timestamp': 300, 'location': 'RL', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 327, 'location': 'LA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '85', 'y': '71'}, {'timestamp': 353, 'location': 'RL', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 358, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '8', 'y': '18'}, {'timestamp': 384, 'location': 'KM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 395, 'location': 'K', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 37, 'player_name': 'Christoph Stadelmaier', 'position': 'RL'}, 'x': '90', 'y': '17'}, {'timestamp': 443, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '24', 'y': '84'}, {'timestamp': 490, 'location': 'RR', 'own_team': True, 'type': 'Tor', 'player': {'number': 17, 'player_name': 'Hans', 'position': 'KM'}, 'x': '85', 'y': '9'}, {'timestamp': 538, 'location': 'RL', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 17, 'player_name': 'Ulf Christiansen', 'position': 'RL'}, 'x': '90', 'y': '82'}, {'timestamp': 583, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 17, 'player_name': 'Florian Denker', 'position': 'KM'}, 'x': '6', 'y': '48'}, {'timestamp': 622, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '84', 'y': '8'}, {'timestamp': 647, 'location': 'RR', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 17, 'player_name': 'Hans', 'position': 'KM'}, 'x': '83', 'y': '13'}, {'timestamp': 674, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '16', 'y': '82'}, {'timestamp': 731, 'location': 'RA', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 87, 'player_name': 'Tobias Heinrich', 'position': 'RR'}, 'x': '17', 'y': '51'}, {'timestamp': 745, 'location': 'R', 'own_team': False, 'type': 'Tor ...
# {'actions': [{'timestamp': 36, 'location': 'RM', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '92', 'y': '35'}, {'timestamp': 64, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '7', 'y': '13'}, {'timestamp': 80, 'location': 'RM', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '90', 'y': '36'}, {'timestamp': 125, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '86', 'y': '12'}, {'timestamp': 135, 'location': 'RM', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 37, 'player_name': 'Christoph Stadelmaier', 'position': 'RL'}, 'x': '10', 'y': '14'}, {'timestamp': 202, 'location': 'L', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '64', 'y': '7'}, {'timestamp': 287, 'location': 'RA', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 87, 'player_name': 'Tobias Heinrich', 'position': 'RR'}, 'x': '32', 'y': '11'}, {'timestamp': 297, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '21', 'y': '9'}, {'timestamp': 372, 'location': 'RR', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '2', 'y': '57'}, {'timestamp': 386, 'location': 'K', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '9', 'y': '30'}, {'timestamp': 400, 'location': 'RM', 'own_team': True, 'type': 'Block', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': None, 'y': None}, {'timestamp': 472, 'location': 'LA', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '4', 'y': '26'}, {'timestamp': 483, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '88', 'y': '68'}, {'timestamp': 513, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '9', 'y': '35'}, {'timestamp': 519, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 87, 'player_name': 'Tobias Heinrich', 'position': 'RR'}, 'x': '90', 'y': '38'}, {'timestamp': 546, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '-1', 'y': '-1'}, {'timestamp': 602, 'location': 'RR', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 655, 'location': 'RL', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 745, 'location': 'RA', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '5', 'y': '77'}, {'timestamp': 783, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 30, 'player_name': 'Nguyen Duc Nam Le', 'position': 'RM'}, 'x': '18', 'y': '16'}, {'timestamp': 817, 'location': 'K', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 828, 'location': 'K', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '12', 'y': '14'}, {'timestamp': 849, 'location': 'KM', 'own_team': True, 'type': 'Tor', 'player': {'number': 21, 'player_name': 'Lasse Nehring', 'position': 'KM'}, 'x': '21', 'y': '12'}, {'timestamp': 900, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '16', 'y': '83'}, {'timestamp': 980, 'location': '7M', 'own_team' ...
# {'actions': [{'timestamp': 32, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '86', 'y': '63'}, {'timestamp': 83, 'location': 'RL', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '93', 'y': '16'}, {'timestamp': 97, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '19', 'y': '6'}, {'timestamp': 118, 'location': 'RM', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '77', 'y': '74'}, {'timestamp': 145, 'location': 'M', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '86', 'y': '40'}, {'timestamp': 174, 'location': 'RM', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '50', 'y': '84'}, {'timestamp': 190, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '56', 'y': '79'}, {'timestamp': 199, 'location': 'RL', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '92', 'y': '70'}, {'timestamp': 228, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '89', 'y': '9'}, {'timestamp': 285, 'location': '7M', 'own_team': True, 'type': 'Tor', 'player': {'number': 2, 'player_name': 'Lars Hunschede', 'position': 'KM'}, 'x': '10', 'y': '15'}, {'timestamp': 308, 'location': 'RM', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 317, 'location': 'R', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '7', 'y': '46'}, {'timestamp': 341, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '7', 'y': '46'}, {'timestamp': 352, 'location': 'K', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 365, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '10', 'y': '19'}, {'timestamp': 394, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 27, 'player_name': 'Niklas Tibbe', 'position': 'KM'}, 'x': '80', 'y': '12'}, {'timestamp': 448, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '8', 'y': '69'}, {'timestamp': 484, 'location': 'RR', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '6', 'y': '26'}, {'timestamp': 491, 'location': 'K', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 500, 'location': 'KM', 'own_team': True, 'type': 'Tor', 'player': {'number': 27, 'player_name': 'Niklas Tibbe', 'position': 'KM'}, 'x': '89', 'y': '22'}, {'timestamp': 531, 'location': 'M', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '90', 'y': '26'}, {'timestamp': 556, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '89', 'y': '15'}, {'timestamp': 571, 'location': 'RA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '89', 'y': '13'}, {'timestamp': 606, 'location': 'RR', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '89', 'y': '14'}, {'timestamp': 618, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'playe ...
# {'actions': [{'timestamp': 63, 'location': 'RL', 'own_team': True, 'type': 'Tor', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '8', 'y': '85'}, {'timestamp': 88, 'location': 'M', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '88', 'y': '74'}, {'timestamp': 95, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '23', 'y': '11'}, {'timestamp': 149, 'location': 'L', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '5', 'y': '40'}, {'timestamp': 159, 'location': 'R', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '78'}, {'timestamp': 174, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '23', 'y': '9'}, {'timestamp': 203, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '72'}, {'timestamp': 234, 'location': 'RR', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 252, 'location': 'RR', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '7', 'y': '24'}, {'timestamp': 285, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '24', 'y': '84'}, {'timestamp': 303, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '8', 'y': '69'}, {'timestamp': 340, 'location': 'KM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 349, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '87', 'y': '62'}, {'timestamp': 355, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '65', 'y': '82'}, {'timestamp': 390, 'location': 'RA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '62'}, {'timestamp': 428, 'location': 'M', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 464, 'location': 'L', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 511, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '7'}, {'timestamp': 521, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 63, 'player_name': 'Nenad PeÅ¡iÄ‡', 'position': 'RR'}, 'x': '4', 'y': '41'}, {'timestamp': 557, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '7', 'y': '16'}, {'timestamp': 595, 'location': 'RA', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '11', 'y': '67'}, {'timestamp': 646, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '83', 'y': '71'}, {'timestamp': 698, 'location': 'RA', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '6', 'y': '70'}, {'timestamp': 726, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '4', 'y': '72'}, {'timestamp': 744, 'location': 'LA', 'own_team': True, 't ...
# {'actions': [{'timestamp': 32, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '4', 'y': '58'}, {'timestamp': 63, 'location': 'RL', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 63, 'player_name': 'Nenad PeÅ¡iÄ‡', 'position': 'RR'}, 'x': '86', 'y': '11'}, {'timestamp': 105, 'location': 'RM', 'own_team': False, 'type': 'Verworfen', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '19', 'y': '87'}, {'timestamp': 112, 'location': 'RA', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '12', 'y': '81'}, {'timestamp': 145, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '92', 'y': '14'}, {'timestamp': 158, 'location': 'R', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '90', 'y': '29'}, {'timestamp': 195, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '80', 'y': '10'}, {'timestamp': 261, 'location': 'LA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '79', 'y': '12'}, {'timestamp': 275, 'location': 'RA', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '5', 'y': '77'}, {'timestamp': 302, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '85', 'y': '25'}, {'timestamp': 334, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 3, 'player_name': 'Ben Louis Vollert', 'position': 'LA'}, 'x': '20', 'y': '15'}, {'timestamp': 363, 'location': 'LA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '9', 'y': '77'}, {'timestamp': 370, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 63, 'player_name': 'Nenad PeÅ¡iÄ‡', 'position': 'RR'}, 'x': '23', 'y': '92'}, {'timestamp': 399, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '6', 'y': '10'}, {'timestamp': 411, 'location': 'RA', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '6', 'y': '78'}, {'timestamp': 468, 'location': 'RR', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '93', 'y': '13'}, {'timestamp': 480, 'location': 'L', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '92', 'y': '65'}, {'timestamp': 523, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '56', 'y': '83'}, {'timestamp': 555, 'location': 'L', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '8', 'y': '55'}, {'timestamp': 582, 'location': 'RM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 634, 'location': 'RM', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 687, 'location': '7M', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '10', 'y': '73'}, {'timestamp': 691, 'location': 'KM', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '90', 'y': '75'}, {'timestamp': 732, 'location': 'RR', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'posi ...
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'timo' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Martin FlieÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Martin FlieÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Martin FlieÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Matthias KloÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Martin FlieÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# {'actions': [{'timestamp': 49, 'location': 'RR', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 51, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 8, 'player_name': 'Valentin', 'position': 'LA'}, 'x': '91', 'y': '16'}, {'timestamp': 66, 'location': 'R', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '90', 'y': '51'}, {'timestamp': 103, 'location': 'RA', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '6', 'y': '68'}, {'timestamp': 112, 'location': 'RM', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 138, 'location': 'KM', 'own_team': True, 'type': 'Tor', 'player': {'number': 2, 'player_name': 'Lars Hunschede', 'position': 'KM'}, 'x': '5', 'y': '27'}, {'timestamp': 146, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '90', 'y': '20'}, {'timestamp': 178, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '92', 'y': '26'}, {'timestamp': 189, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '7', 'y': '26'}, {'timestamp': 225, 'location': 'R', 'own_team': True, 'type': 'Tor', 'player': {'number': 30, 'player_name': 'Nguyen Duc Nam Le', 'position': 'RM'}, 'x': '89', 'y': '19'}, {'timestamp': 240, 'location': 'KM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '91', 'y': '46'}, {'timestamp': 262, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '10', 'y': '13'}, {'timestamp': 306, 'location': 'RM', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 30, 'player_name': 'Nguyen Duc Nam Le', 'position': 'RM'}, 'x': '80', 'y': '36'}, {'timestamp': 316, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '39', 'y': '85'}, {'timestamp': 346, 'location': 'RA', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '9', 'y': '74'}, {'timestamp': 371, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '31', 'y': '11'}, {'timestamp': 456, 'location': 'RR', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 466, 'location': 'R', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '7', 'y': '17'}, {'timestamp': 497, 'location': 'RM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 551, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '11', 'y': '75'}, {'timestamp': 562, 'location': 'RR', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 610, 'location': 'R', 'own_team': True, 'type': 'Tor', 'player': {'number': 9, 'player_name': 'Momme Funda', 'position': 'RM'}, 'x': '90', 'y': '74'}, {'timestamp': 650, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 8, 'player_name': 'Valentin', 'position': 'LA'}, 'x': '86', 'y': '11'}, {'timestamp': 680, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 81, 'player_name': 'Martin FlieÃŸ', 'position': 'TW'}, 'x': '8', 'y': '19'}, {'timestamp': 704, 'location': 'RA', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '40', 'y': '73'}, {'timestamp ...
# {'actions': [{'timestamp': 63, 'location': 'RL', 'own_team': True, 'type': 'Tor', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '8', 'y': '85'}, {'timestamp': 88, 'location': 'M', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '88', 'y': '74'}, {'timestamp': 95, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '23', 'y': '11'}, {'timestamp': 149, 'location': 'L', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 45, 'player_name': 'Matthias KloÃŸ', 'position': 'RL'}, 'x': '5', 'y': '40'}, {'timestamp': 159, 'location': 'R', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '78'}, {'timestamp': 174, 'location': 'L', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '23', 'y': '9'}, {'timestamp': 203, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '72'}, {'timestamp': 234, 'location': 'RR', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 252, 'location': 'RR', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '7', 'y': '24'}, {'timestamp': 285, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 34, 'player_name': 'Philippe Moreau', 'position': 'RM'}, 'x': '24', 'y': '84'}, {'timestamp': 303, 'location': 'LA', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '8', 'y': '69'}, {'timestamp': 340, 'location': 'KM', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 349, 'location': 'RM', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '87', 'y': '62'}, {'timestamp': 355, 'location': 'K', 'own_team': True, 'type': 'Tor', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '65', 'y': '82'}, {'timestamp': 390, 'location': 'RA', 'own_team': False, 'type': 'Gehalten', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '62'}, {'timestamp': 428, 'location': 'M', 'own_team': False, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 464, 'location': 'L', 'own_team': True, 'type': 'Fehler', 'player': None, 'x': None, 'y': None}, {'timestamp': 511, 'location': 'KM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '89', 'y': '7'}, {'timestamp': 521, 'location': 'M', 'own_team': True, 'type': 'Tor', 'player': {'number': 63, 'player_name': 'Nenad PeÅ¡iÄ‡', 'position': 'RR'}, 'x': '4', 'y': '41'}, {'timestamp': 557, 'location': 'RA', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '7', 'y': '16'}, {'timestamp': 595, 'location': 'RA', 'own_team': True, 'type': 'Gehalten', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '11', 'y': '67'}, {'timestamp': 646, 'location': '7M', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '83', 'y': '71'}, {'timestamp': 698, 'location': 'RA', 'own_team': True, 'type': 'Verworfen', 'player': {'number': 28, 'player_name': 'Brian Mathias JÃ¤ger', 'position': 'LA'}, 'x': '6', 'y': '70'}, {'timestamp': 726, 'location': 'RM', 'own_team': False, 'type': 'Tor', 'player': {'number': 31, 'player_name': 'Sebastian Niemann', 'position': 'TW'}, 'x': '4', 'y': '72'}, {'timestamp': 744, 'location': 'LA', 'own_team': True, 't ...
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Valentin' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# c:\Users\timod\OneDrive\Documents\Projekte\Programmieren\handball_analytics\handball_stats_visualisations\parsing.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Matthias KloÃŸ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'player_name'] = data.loc[i, 'player']['player_name']
# PDF wurde erstellt.
